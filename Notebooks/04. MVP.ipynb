# %% [markdown]
# # 04. MVP:

# %% [markdown]
# The target of this notebook is to build a minimum viable product to test the idea and see if it works

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ## Data Visulitation

# %%
cars = ('/users/alfon/Desktop/Master/TFM/CSV/cars_final.csv')

# %%
df = pd.read_csv(cars)

df.head()
# Out:
#         Brand   Model                                 Version Category  Year  \
# 0        Fiat    Tipo                                1.4 Easy    Small  2017
# 1        SEAT    Leon  2.0TDI CR S&S FR Fast Edition DSG7 150    Small  2020
# 2        Audi      A3    Sportback 1.6TDI Design Edition 81kW    Small  2017
# 3       Honda   Civic            1.0 VTEC Turbo Elegance Navi    Small  2018
# 4  Volkswagen  Beetle                       1.4 TSI Sport 160    Small  2013
#
#       Kms   Hp  Gear_type Fuel_type  Fuel_cons  Doors Colour    ZIP  \
# 0   24000   95     Manual    Petrol        6.5      5  Beige  43001
# 1   14122  150  Automatic    Diesel        4.3      5   Blue  43006
# 2   65290  110     Manual    Diesel        3.9      5   Blue  43006
# 3   54189  129     Manual    Petrol        5.1      5   Blue  43204
# 4  105300  159     Manual    Petrol        6.6      5  Brown  43001
#
#     Province  Price_EUR
# 0  Tarragona      10900
# 1  Tarragona      24200
# 2  Tarragona      19200
# 3  Tarragona      18900
# 4  Tarragona      19900

# %%
sns.pairplot(df)

# %%
corr = df.corr()
corr.style.background_gradient(cmap="coolwarm", vmin=-1, vmax=1).set_precision(2)
# Out:
# /var/folders/8d/r5dgt6bd65964tjj89vgvwh40000gn/T/ipykernel_9471/543077139.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap="coolwarm", vmin=-1, vmax=1).set_precision(2)
# <style type="text/css">
# #T_82b64_row0_col0, #T_82b64_row1_col1, #T_82b64_row2_col2, #T_82b64_row3_col3, #T_82b64_row4_col4, #T_82b64_row5_col5, #T_82b64_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_82b64_row0_col1, #T_82b64_row1_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_82b64_row0_col2, #T_82b64_row2_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_82b64_row0_col3, #T_82b64_row3_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_82b64_row0_col4, #T_82b64_row4_col0 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_82b64_row0_col5, #T_82b64_row5_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_82b64_row0_col6, #T_82b64_row6_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_82b64_row1_col2, #T_82b64_row2_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_82b64_row1_col3, #T_82b64_row3_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_82b64_row1_col4, #T_82b64_row4_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_82b64_row1_col5, #T_82b64_row5_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_82b64_row1_col6, #T_82b64_row6_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_82b64_row2_col3, #T_82b64_row3_col2 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_82b64_row2_col4, #T_82b64_row4_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_82b64_row2_col5, #T_82b64_row5_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_82b64_row2_col6, #T_82b64_row6_col2 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_82b64_row3_col4, #T_82b64_row4_col3 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_82b64_row3_col5, #T_82b64_row5_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_82b64_row3_col6, #T_82b64_row6_col3 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_82b64_row4_col5, #T_82b64_row5_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_82b64_row4_col6, #T_82b64_row6_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_82b64_row5_col6, #T_82b64_row6_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# </style>
# <table id="T_82b64_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year</th>
#       <th class="col_heading level0 col1" >Kms</th>
#       <th class="col_heading level0 col2" >Hp</th>
#       <th class="col_heading level0 col3" >Fuel_cons</th>
#       <th class="col_heading level0 col4" >Doors</th>
#       <th class="col_heading level0 col5" >ZIP</th>
#       <th class="col_heading level0 col6" >Price_EUR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82b64_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_82b64_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_82b64_row0_col1" class="data row0 col1" >-0.60</td>
#       <td id="T_82b64_row0_col2" class="data row0 col2" >0.02</td>
#       <td id="T_82b64_row0_col3" class="data row0 col3" >-0.43</td>
#       <td id="T_82b64_row0_col4" class="data row0 col4" >0.15</td>
#       <td id="T_82b64_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_82b64_row0_col6" class="data row0 col6" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_82b64_level0_row1" class="row_heading level0 row1" >Kms</th>
#       <td id="T_82b64_row1_col0" class="data row1 col0" >-0.60</td>
#       <td id="T_82b64_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_82b64_row1_col2" class="data row1 col2" >-0.11</td>
#       <td id="T_82b64_row1_col3" class="data row1 col3" >0.10</td>
#       <td id="T_82b64_row1_col4" class="data row1 col4" >0.04</td>
#       <td id="T_82b64_row1_col5" class="data row1 col5" >0.04</td>
#       <td id="T_82b64_row1_col6" class="data row1 col6" >-0.27</td>
#     </tr>
#     <tr>
#       <th id="T_82b64_level0_row2" class="row_heading level0 row2" >Hp</th>
#       <td id="T_82b64_row2_col0" class="data row2 col0" >0.02</td>
#       <td id="T_82b64_row2_col1" class="data row2 col1" >-0.11</td>
#       <td id="T_82b64_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_82b64_row2_col3" class="data row2 col3" >0.66</td>
#       <td id="T_82b64_row2_col4" class="data row2 col4" >-0.44</td>
#       <td id="T_82b64_row2_col5" class="data row2 col5" >-0.02</td>
#       <td id="T_82b64_row2_col6" class="data row2 col6" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_82b64_level0_row3" class="row_heading level0 row3" >Fuel_cons</th>
#       <td id="T_82b64_row3_col0" class="data row3 col0" >-0.43</td>
#       <td id="T_82b64_row3_col1" class="data row3 col1" >0.10</td>
#       <td id="T_82b64_row3_col2" class="data row3 col2" >0.66</td>
#       <td id="T_82b64_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_82b64_row3_col4" class="data row3 col4" >-0.41</td>
#       <td id="T_82b64_row3_col5" class="data row3 col5" >-0.03</td>
#       <td id="T_82b64_row3_col6" class="data row3 col6" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_82b64_level0_row4" class="row_heading level0 row4" >Doors</th>
#       <td id="T_82b64_row4_col0" class="data row4 col0" >0.15</td>
#       <td id="T_82b64_row4_col1" class="data row4 col1" >0.04</td>
#       <td id="T_82b64_row4_col2" class="data row4 col2" >-0.44</td>
#       <td id="T_82b64_row4_col3" class="data row4 col3" >-0.41</td>
#       <td id="T_82b64_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_82b64_row4_col5" class="data row4 col5" >0.03</td>
#       <td id="T_82b64_row4_col6" class="data row4 col6" >-0.30</td>
#     </tr>
#     <tr>
#       <th id="T_82b64_level0_row5" class="row_heading level0 row5" >ZIP</th>
#       <td id="T_82b64_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_82b64_row5_col1" class="data row5 col1" >0.04</td>
#       <td id="T_82b64_row5_col2" class="data row5 col2" >-0.02</td>
#       <td id="T_82b64_row5_col3" class="data row5 col3" >-0.03</td>
#       <td id="T_82b64_row5_col4" class="data row5 col4" >0.03</td>
#       <td id="T_82b64_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_82b64_row5_col6" class="data row5 col6" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_82b64_level0_row6" class="row_heading level0 row6" >Price_EUR</th>
#       <td id="T_82b64_row6_col0" class="data row6 col0" >0.19</td>
#       <td id="T_82b64_row6_col1" class="data row6 col1" >-0.27</td>
#       <td id="T_82b64_row6_col2" class="data row6 col2" >0.73</td>
#       <td id="T_82b64_row6_col3" class="data row6 col3" >0.40</td>
#       <td id="T_82b64_row6_col4" class="data row6 col4" >-0.30</td>
#       <td id="T_82b64_row6_col5" class="data row6 col5" >-0.01</td>
#       <td id="T_82b64_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Machine Learning

# %%
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = df[df.select_dtypes('number').columns[:-1]]
y = df[df.columns[-1]]

# %%
X.shape, y.shape
# Out:
# ((20015, 6), (20015,))

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size = .2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([ 7606.06926434, 10537.90475209, 38763.9336693 , ...,
#        21473.27100908, -2638.26171153, 16701.34113052])

# %% [markdown]
# ## Model Evaluation
